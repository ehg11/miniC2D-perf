# %%
import numpy as np
import json
import re
import sys

# %%
CTAGS_FNS = "./ctags.txt"
PERF_FOLDED = "perf_results/ais10.cnf-perf.log"

# %%
def match_main_line(line):
    children_pct_pattern = r"\s*(?P<children_pct>\d+\.\d+)%"
    self_pct_pattern = r"\s+(?P<self_pct>\d+\.\d+)%"
    command_pattern = r"\s+(?P<command>\S+)"
    sharedobject_pattern = r"\s+(?P<sharedobject>\S+)"
    symbol_pattern = r"\s+\[\.\]\s+(?P<symbol>\S+)"
    pattern = (
        "^" +
        children_pct_pattern +
        self_pct_pattern +
        command_pattern +
        sharedobject_pattern +
        symbol_pattern +
        "$"
    )

    match = re.match(pattern, line)
    if match:
        res = match.groupdict()
        res['children_pct'] = float(res['children_pct'])
        res['self_pct'] = float(res['self_pct'])
        return res
    else:
        return None

# %%
main_lines = []

with open(PERF_FOLDED, "r") as f:
    lines = f.readlines()
    for line in lines:
        line = line.strip()
        res = match_main_line(line)
        if res:
            main_lines.append(res)

main_lines.sort(key=lambda r: r["self_pct"], reverse=True)
main_lines
# Out:
# [{'children_pct': 56.32,
#   'self_pct': 34.51,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'set_literal'},
#  {'children_pct': 17.73,
#   'self_pct': 14.21,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'construct_vtree_key'},
#  {'children_pct': 12.35,
#   'self_pct': 12.35,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'remove_watched_clause'},
#  {'children_pct': 17.34,
#   'self_pct': 4.99,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'move_watched_literal'},
#  {'children_pct': 3.13,
#   'self_pct': 3.13,
#   'command': 'miniC2D',
#   'sharedobject': 'libstdc++.so.6.0.30',
#   'symbol': 'std::_Rb_tree_increment'},
#  {'children_pct': 2.06,
#   'self_pct': 2.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_is_subsumed_clause'},
#  {'children_pct': 2.02,
#   'self_pct': 2.02,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'mark_vars_at_level'},
#  {'children_pct': 2.0,
#   'self_pct': 2.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'erase_level'},
#  {'children_pct': 3.87,
#   'self_pct': 1.85,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'zchaff_conflict_clause'},
#  {'children_pct': 1.53,
#   'self_pct': 1.53,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_mark_var'},
#  {'children_pct': 1.82,
#   'self_pct': 1.34,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'get_and_node'},
#  {'children_pct': 1.27,
#   'self_pct': 1.27,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_is_implied_literal'},
#  {'children_pct': 19.96,
#   'self_pct': 1.2,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'lookup_cache'},
#  {'children_pct': 1.08,
#   'self_pct': 1.08,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'Graph::containsEdge'},
#  {'children_pct': 0.92,
#   'self_pct': 0.92,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_unmark_var'},
#  {'children_pct': 2.43,
#   'self_pct': 0.9,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'mark_vset'},
#  {'children_pct': 0.78,
#   'self_pct': 0.78,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_is_marked_var'},
#  {'children_pct': 0.78,
#   'self_pct': 0.78,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vtree_is_shannon_node'},
#  {'children_pct': 2.4,
#   'self_pct': 0.73,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vset_union'},
#  {'children_pct': 82.39,
#   'self_pct': 0.72,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'compile_dispatcher'},
#  {'children_pct': 6.13,
#   'self_pct': 0.64,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'Graph::removeAndConnect'},
#  {'children_pct': 0.62,
#   'self_pct': 0.62,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'free_vtree_cache'},
#  {'children_pct': 1.53,
#   'self_pct': 0.61,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'unmark_vset'},
#  {'children_pct': 0.61,
#   'self_pct': 0.61,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cset_subset'},
#  {'children_pct': 0.59,
#   'self_pct': 0.59,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'clist_size'},
#  {'children_pct': 82.39,
#   'self_pct': 0.55,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'compile_vtree_shannon'},
#  {'children_pct': 0.6,
#   'self_pct': 0.54,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': 'malloc'},
#  {'children_pct': 0.92,
#   'self_pct': 0.3,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '__libc_calloc'},
#  {'children_pct': 0.3,
#   'self_pct': 0.3,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': 'cfree'},
#  {'children_pct': 0.24,
#   'self_pct': 0.24,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a273f'},
#  {'children_pct': 0.19,
#   'self_pct': 0.19,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_var2pliteral'},
#  {'children_pct': 0.19,
#   'self_pct': 0.19,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_is_instantiated_var'},
#  {'children_pct': 0.3,
#   'self_pct': 0.18,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'insert_cache'},
#  {'children_pct': 0.18,
#   'self_pct': 0.18,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_clause2literals'},
#  {'children_pct': 0.18,
#   'self_pct': 0.18,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'drop_vtree_cache_entries'},
#  {'children_pct': 0.18,
#   'self_pct': 0.18,
#   'command': 'miniC2D',
#   'sharedobject': 'libstdc++.so.6.0.30',
#   'symbol': 'std::_Rb_tree_insert_and_rebalance'},
#  {'children_pct': 2.01,
#   'self_pct': 0.13,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vset_intersection'},
#  {'children_pct': 1.03,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vset_new'},
#  {'children_pct': 0.33,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': 'realloc'},
#  {'children_pct': 0.12,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000001a0826'},
#  {'children_pct': 0.12,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a27d1'},
#  {'children_pct': 0.12,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'add_watched_clause'},
#  {'children_pct': 0.12,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'literal2nnf_node'},
#  {'children_pct': 0.12,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a3f9b'},
#  {'children_pct': 0.12,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000001a0f80'},
#  {'children_pct': 0.12,
#   'self_pct': 0.12,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vtree_shannon_var'},
#  {'children_pct': 0.11,
#   'self_pct': 0.11,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_mark_clause'},
#  {'children_pct': 0.11,
#   'self_pct': 0.11,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'nnf_node_cmp'},
#  {'children_pct': 0.07,
#   'self_pct': 0.07,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a3cfd'},
#  {'children_pct': 8.09,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'classify_clause_vars'},
#  {'children_pct': 2.38,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vset_minus'},
#  {'children_pct': 0.54,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': 'qsort_r'},
#  {'children_pct': 0.49,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vset_clause_new'},
#  {'children_pct': 0.18,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'add_clause'},
#  {'children_pct': 0.12,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'var2nnf'},
#  {'children_pct': 0.12,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'Graph::removeEdge'},
#  {'children_pct': 0.12,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_state_free'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a39d4'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a489b'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a4088'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a3cd5'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x000000000004444b'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_is_irrelevant_var'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a26ad'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a4b44'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x0000000000044411'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a18d6'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_literal2var'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'eset_free'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a1723'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a27a2'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a2709'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a4b5e'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x0000000000044427'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_var2nliteral'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'eset_node_new'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a4b37'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a2735'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a3e06'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'eset_intersection'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'mark_eset'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a2806'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sift_up'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a3d74'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'count_nnf_nodes'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000001a081b'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x0000000000075188'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a28f1'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a3e62'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x000000000007660f'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'free@plt'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x0000000000044467'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000001a0ffc'},
#  {'children_pct': 0.06,
#   'self_pct': 0.06,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_unmark_clause'},
#  {'children_pct': 41.54,
#   'self_pct': 0.05,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_decide_literal'},
#  {'children_pct': 0.11,
#   'self_pct': 0.05,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'unmark_cset'},
#  {'children_pct': 0.05,
#   'self_pct': 0.05,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000001a1029'},
#  {'children_pct': 0.02,
#   'self_pct': 0.02,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00000000000a3a52'},
#  {'children_pct': 0.02,
#   'self_pct': 0.02,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '_IO_sputbackc'},
#  {'children_pct': 0.02,
#   'self_pct': 0.02,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x0000000000064003'},
#  {'children_pct': 0.01,
#   'self_pct': 0.01,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x0000000000199d83'},
#  {'children_pct': 0.01,
#   'self_pct': 0.01,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x000000000000b791'},
#  {'children_pct': 68.2,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': '[unknown]',
#   'symbol': '0xffffffffffffffff'},
#  {'children_pct': 33.48,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'main'},
#  {'children_pct': 32.76,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810b0d8f'},
#  {'children_pct': 31.5,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '__libc_start_main'},
#  {'children_pct': 31.32,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': '_start'},
#  {'children_pct': 16.76,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'compile_vtree'},
#  {'children_pct': 15.47,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vtree_manager_new'},
#  {'children_pct': 15.47,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cnf2vtree'},
#  {'children_pct': 15.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_assert_clause'},
#  {'children_pct': 8.93,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'p_hdtree2vtree'},
#  {'children_pct': 8.82,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'pass2'},
#  {'children_pct': 6.45,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cnf2hdtree'},
#  {'children_pct': 6.39,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cnf2minfill_order'},
#  {'children_pct': 4.78,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'compile_vtree_decomposed'},
#  {'children_pct': 4.47,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'analyze_conflict'},
#  {'children_pct': 0.68,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vtree_manager_free'},
#  {'children_pct': 0.6,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'vset_free'},
#  {'children_pct': 0.59,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'print_vtree_cache_stats'},
#  {'children_pct': 0.24,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112973f'},
#  {'children_pct': 0.22,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'pass1b'},
#  {'children_pct': 0.18,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'save_nnf_manager_to_file'},
#  {'children_pct': 0.18,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'save_nnf_nodes'},
#  {'children_pct': 0.18,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'minFillScore'},
#  {'children_pct': 0.16,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cset_intersection'},
#  {'children_pct': 0.12,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81227826'},
#  {'children_pct': 0.12,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e811297d1'},
#  {'children_pct': 0.12,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'declare_watched_literals'},
#  {'children_pct': 0.12,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112af9b'},
#  {'children_pct': 0.12,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81227f80'},
#  {'children_pct': 0.11,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cset_union'},
#  {'children_pct': 0.11,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'mark_cset'},
#  {'children_pct': 0.11,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810cb40e'},
#  {'children_pct': 0.07,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112acfd'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112a9d4'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112b89b'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112b088'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112acd5'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810cb44b'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e811296ad'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112bb44'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810cb411'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'free_hgr'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81129e9f'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e811288d6'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'free_hdtree'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112b62a'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81128723'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e811297a2'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81129709'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112bb5e'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810cb427'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': '[heap]',
#   'symbol': '0x000000002984979f'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112b8b0'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'order2hdtree'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112bb37'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81129735'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112ae06'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'fill_esets'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'fill_edges_etc'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'eset_union'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81129806'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112ad74'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810fcca8'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '_IO_file_xsputn'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8122781b'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810fc188'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e811298f1'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112ae62'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810fd60f'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'p_hdtree2vtree_aux'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cutset2vtree_rl'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'combine_v'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cset_new'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8122804a'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': '[unknown]',
#   'symbol': '0xffffffff8e000c02'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': '[unknown]',
#   'symbol': '0xffffffff8df2559d'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': '[unknown]',
#   'symbol': '0xffffffff8d0e5a2f'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'free_manager_keys'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810cb467'},
#  {'children_pct': 0.06,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81227ffc'},
#  {'children_pct': 0.05,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81228029'},
#  {'children_pct': 0.03,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'sat_read_cnf'},
#  {'children_pct': 0.03,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': 'fscanf'},
#  {'children_pct': 0.03,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'Graph::Graph'},
#  {'children_pct': 0.03,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'Graph::addEdge'},
#  {'children_pct': 0.02,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'cnf2hgr_primal'},
#  {'children_pct': 0.02,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'miniC2D',
#   'symbol': 'declare_in_hgr'},
#  {'children_pct': 0.02,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112bb89'},
#  {'children_pct': 0.02,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e8112aa52'},
#  {'children_pct': 0.02,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810ea06c'},
#  {'children_pct': 0.02,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e810eb003'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152d297'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152e597'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libstdc++.so.6.0.30',
#   'symbol': 'std::ios_base::Init::Init'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libstdc++.so.6.0.30',
#   'symbol': 'std::locale::locale'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libstdc++.so.6.0.30',
#   'symbol': '0x00007f7e813922f3'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libstdc++.so.6.0.30',
#   'symbol': 'std::locale::_Impl::_Impl'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libstdc++.so.6.0.30',
#   'symbol': 'std::ctype<wchar_t>::_M_initialize_ctype'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'libc.so.6',
#   'symbol': '0x00007f7e81220d83'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152c83b'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e81530a62'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8151e4e7'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e81519210'},
#  {'children_pct': 0.01,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e81518791'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00000000000162af'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e81530510'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152a451'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152df0b'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e815235dc'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e815232af'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x000000000001867e'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152c7f2'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152672b'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152567e'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x000000000002134a'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152e34a'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152e5d3'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00000000000215d3'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152e055'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152d293'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x00007f7e8152d290'},
#  {'children_pct': 0.0,
#   'self_pct': 0.0,
#   'command': 'miniC2D',
#   'sharedobject': 'ld-linux-x86-64.so.2',
#   'symbol': '0x0000000000020293'}]

# %%
total_self_time = 0
for line in main_lines:
    total_self_time += line["self_pct"]

total_self_time
# Out:
# 98.90000000000015

# %%
# redoing target functions with ctags

target_functions = []
with open(CTAGS_FNS, "r") as f:
    for line in f.readlines():
        line = line.strip()
        fn_name = line.split(maxsplit=1)[0]

        target_functions.append(fn_name)

target_functions = set(target_functions)
target_functions
# Out:
# {'allocate_manager_keys',
#  'allocate_vtree_keys',
#  'bits2bytes',
#  'c2d_version',
#  'clist_size',
#  'compile_dispatcher',
#  'compile_vtree',
#  'compile_vtree_decomposed',
#  'compile_vtree_leaf',
#  'compile_vtree_shannon',
#  'compile_with_literal',
#  'construct_vtree_cache',
#  'construct_vtree_key',
#  'copy_key',
#  'count_dispatcher',
#  'count_vtree',
#  'count_vtree_decomposed',
#  'count_vtree_leaf',
#  'count_vtree_shannon',
#  'count_with_literal',
#  'drop_cache_entry',
#  'drop_vtree_cache_entries',
#  'extended_file_name',
#  'free_cache_entry',
#  'free_manager_keys',
#  'free_vtree_cache',
#  'free_vtree_keys',
#  'get_options',
#  'init_options',
#  'insert_cache',
#  'lookup_cache',
#  'main',
#  'match_keys',
#  'nnf_conjoin',
#  'nnf_count_models',
#  'nnf_count_nodes',
#  'nnf_decomposable',
#  'nnf_disjoin',
#  'nnf_edge_count',
#  'nnf_entails_cnf',
#  'nnf_free',
#  'nnf_literal2node',
#  'nnf_load_from_file',
#  'nnf_manager_extract_nnf',
#  'nnf_manager_free',
#  'nnf_manager_get_root',
#  'nnf_manager_memory',
#  'nnf_manager_new',
#  'nnf_manager_save_to_file',
#  'nnf_manager_set_root',
#  'nnf_node_count',
#  'nnf_save_as_dot',
#  'nnf_save_to_file',
#  'pprint_bytes',
#  'print_error_and_exit',
#  'print_help',
#  'print_vtree_cache_stats',
#  'sat_assert_clause',
#  'sat_assert_unit_clauses',
#  'sat_at_assertion_level',
#  'sat_clause2index',
#  'sat_clause2literals',
#  'sat_clause_count',
#  'sat_clause_of_var',
#  'sat_clause_size',
#  'sat_decide_literal',
#  'sat_index2clause',
#  'sat_index2literal',
#  'sat_index2var',
#  'sat_is_implied_literal',
#  'sat_is_instantiated_var',
#  'sat_is_irrelevant_var',
#  'sat_is_marked_clause',
#  'sat_is_marked_var',
#  'sat_is_subsumed_clause',
#  'sat_learned_clause_count',
#  'sat_literal2index',
#  'sat_literal2var',
#  'sat_literal_weight',
#  'sat_mark_clause',
#  'sat_mark_var',
#  'sat_state_free',
#  'sat_state_new',
#  'sat_undo_assert_unit_clauses',
#  'sat_undo_decide_literal',
#  'sat_unmark_clause',
#  'sat_unmark_var',
#  'sat_var2index',
#  'sat_var2nliteral',
#  'sat_var2pliteral',
#  'sat_var_count',
#  'sat_var_occurences',
#  'set_vtree_hashcode',
#  'should_cache',
#  'var2count',
#  'var2nnf',
#  'vtree_is_leaf',
#  'vtree_is_shannon_node',
#  'vtree_manager_free',
#  'vtree_manager_new',
#  'vtree_print_widths',
#  'vtree_save',
#  'vtree_save_as_dot',
#  'vtree_shannon_var',
#  'vtree_type'}

# %%
# folded analysis

# PERF_FOLDED = "perf_results_folded.txt"
# PERF_FOLDED = "mini_test.txt"

fn_pcts = {}
for fn in target_functions:
    fn_pcts[fn] = 0
# fn_pcts = { "construct_vtree_key": 0 }

with open(PERF_FOLDED, "r") as f:
    lines = f.readlines()
    current_fn = None
    skip_section = False
    for i, line in enumerate(lines):
        line = line.strip()
        if len(line) == 0:
            break
        if line[0] == "#":
            continue
        res = match_main_line(line)
        if res:
            current_fn = res["symbol"]
            if current_fn not in target_functions:
                skip_section = True
                continue
            skip_section = False
            fn_pcts[current_fn] += res["self_pct"]
        else:
            if skip_section:
                continue
            pct, callstack = line.split(maxsplit=1)
            pct = float(pct.replace('%', ''))
            callstack = callstack.split(";")
            if callstack[0] == current_fn:
                callstack = callstack[1:]
            callstack = set(callstack)
            contains_other_targets = len(callstack.intersection(target_functions)) > 0
            if contains_other_targets:
                continue
            else:
                fn_pcts[current_fn] += pct
fn_pcts
# Out:
# {'insert_cache': 0.6900000000000001,
#  'vtree_manager_new': 11.860000000000017,
#  'pprint_bytes': 0,
#  'vtree_shannon_var': 0.12,
#  'copy_key': 0,
#  'set_vtree_hashcode': 0,
#  'sat_at_assertion_level': 0,
#  'sat_clause2index': 0,
#  'nnf_literal2node': 0,
#  'print_error_and_exit': 0,
#  'count_with_literal': 0,
#  'print_vtree_cache_stats': 0.0,
#  'sat_literal2var': 0.06,
#  'clist_size': 0.59,
#  'vtree_save': 0,
#  'nnf_entails_cnf': 0,
#  'free_cache_entry': 0,
#  'nnf_save_to_file': 0,
#  'sat_is_marked_var': 0.78,
#  'construct_vtree_cache': 0,
#  'sat_clause2literals': 0.18,
#  'print_help': 0,
#  'drop_vtree_cache_entries': 0.18,
#  'drop_cache_entry': 0,
#  'c2d_version': 0,
#  'nnf_manager_get_root': 0,
#  'free_vtree_cache': 0.62,
#  'sat_unmark_var': 0.92,
#  'sat_state_free': 0.12,
#  'vtree_type': 0,
#  'vtree_is_leaf': 0,
#  'sat_is_irrelevant_var': 0.06,
#  'free_vtree_keys': 0,
#  'sat_clause_of_var': 0,
#  'sat_var2index': 0,
#  'sat_literal2index': 0,
#  'sat_assert_unit_clauses': 0,
#  'sat_var2nliteral': 0.06,
#  'nnf_count_nodes': 0,
#  'sat_undo_assert_unit_clauses': 0,
#  'allocate_vtree_keys': 0,
#  'sat_decide_literal': 41.54,
#  'nnf_manager_save_to_file': 0,
#  'nnf_manager_set_root': 0,
#  'nnf_free': 0,
#  'sat_is_marked_clause': 0,
#  'sat_index2var': 0,
#  'sat_var2pliteral': 0.19,
#  'lookup_cache': 1.26,
#  'sat_var_count': 0,
#  'get_options': 0,
#  'sat_assert_clause': 15.01,
#  'sat_learned_clause_count': 0,
#  'nnf_manager_new': 0,
#  'sat_undo_decide_literal': 0,
#  'count_vtree': 0,
#  'count_dispatcher': 0,
#  'sat_unmark_clause': 0.06,
#  'nnf_save_as_dot': 0,
#  'var2nnf': 0.06,
#  'nnf_manager_extract_nnf': 0,
#  'count_vtree_leaf': 0,
#  'sat_mark_var': 1.53,
#  'construct_vtree_key': 14.21,
#  'compile_dispatcher': 0.72,
#  'vtree_manager_free': 0.0,
#  'sat_index2clause': 0,
#  'extended_file_name': 0,
#  'nnf_conjoin': 0,
#  'nnf_disjoin': 0,
#  'sat_clause_size': 0,
#  'sat_literal_weight': 0,
#  'bits2bytes': 0,
#  'nnf_manager_free': 0,
#  'init_options': 0,
#  'sat_clause_count': 0,
#  'nnf_decomposable': 0,
#  'var2count': 0,
#  'count_vtree_shannon': 0,
#  'sat_var_occurences': 0,
#  'compile_with_literal': 0,
#  'sat_state_new': 0,
#  'sat_index2literal': 0,
#  'free_manager_keys': 0.18,
#  'nnf_node_count': 0,
#  'should_cache': 0,
#  'vtree_print_widths': 0,
#  'vtree_save_as_dot': 0,
#  'compile_vtree_leaf': 0,
#  'main': 0.18,
#  'nnf_edge_count': 0,
#  'sat_mark_clause': 0.11,
#  'allocate_manager_keys': 0,
#  'nnf_manager_memory': 0,
#  'nnf_count_models': 0,
#  'nnf_load_from_file': 0,
#  'vtree_is_shannon_node': 1.58,
#  'compile_vtree': 0.0,
#  'sat_is_subsumed_clause': 2.06,
#  'sat_is_instantiated_var': 0.19,
#  'compile_vtree_shannon': 0.55,
#  'match_keys': 0,
#  'sat_is_implied_literal': 3.440000000000001,
#  'count_vtree_decomposed': 0,
#  'compile_vtree_decomposed': 0.0}

# %%
total_pct = 0
for fn, pct in fn_pcts.items():
    total_pct += pct

print(total_pct)
sorted_fn_pcts = sorted(list(fn_pcts.items()), key=lambda x: x[1], reverse=True)
if total_pct > 100:
    # normalize
    for i, (fn, pct) in enumerate(sorted_fn_pcts):
        norm_pct = pct / total_pct * 100
        sorted_fn_pcts[i] = (fn, norm_pct)
sorted_fn_pcts
# Out:
# 99.11000000000003
# [('sat_decide_literal', 41.54),
#  ('sat_assert_clause', 15.01),
#  ('construct_vtree_key', 14.21),
#  ('vtree_manager_new', 11.860000000000017),
#  ('sat_is_implied_literal', 3.440000000000001),
#  ('sat_is_subsumed_clause', 2.06),
#  ('vtree_is_shannon_node', 1.58),
#  ('sat_mark_var', 1.53),
#  ('lookup_cache', 1.26),
#  ('sat_unmark_var', 0.92),
#  ('sat_is_marked_var', 0.78),
#  ('compile_dispatcher', 0.72),
#  ('insert_cache', 0.6900000000000001),
#  ('free_vtree_cache', 0.62),
#  ('clist_size', 0.59),
#  ('compile_vtree_shannon', 0.55),
#  ('sat_var2pliteral', 0.19),
#  ('sat_is_instantiated_var', 0.19),
#  ('sat_clause2literals', 0.18),
#  ('drop_vtree_cache_entries', 0.18),
#  ('free_manager_keys', 0.18),
#  ('main', 0.18),
#  ('vtree_shannon_var', 0.12),
#  ('sat_state_free', 0.12),
#  ('sat_mark_clause', 0.11),
#  ('sat_literal2var', 0.06),
#  ('sat_is_irrelevant_var', 0.06),
#  ('sat_var2nliteral', 0.06),
#  ('sat_unmark_clause', 0.06),
#  ('var2nnf', 0.06),
#  ('pprint_bytes', 0),
#  ('copy_key', 0),
#  ('set_vtree_hashcode', 0),
#  ('sat_at_assertion_level', 0),
#  ('sat_clause2index', 0),
#  ('nnf_literal2node', 0),
#  ('print_error_and_exit', 0),
#  ('count_with_literal', 0),
#  ('print_vtree_cache_stats', 0.0),
#  ('vtree_save', 0),
#  ('nnf_entails_cnf', 0),
#  ('free_cache_entry', 0),
#  ('nnf_save_to_file', 0),
#  ('construct_vtree_cache', 0),
#  ('print_help', 0),
#  ('drop_cache_entry', 0),
#  ('c2d_version', 0),
#  ('nnf_manager_get_root', 0),
#  ('vtree_type', 0),
#  ('vtree_is_leaf', 0),
#  ('free_vtree_keys', 0),
#  ('sat_clause_of_var', 0),
#  ('sat_var2index', 0),
#  ('sat_literal2index', 0),
#  ('sat_assert_unit_clauses', 0),
#  ('nnf_count_nodes', 0),
#  ('sat_undo_assert_unit_clauses', 0),
#  ('allocate_vtree_keys', 0),
#  ('nnf_manager_save_to_file', 0),
#  ('nnf_manager_set_root', 0),
#  ('nnf_free', 0),
#  ('sat_is_marked_clause', 0),
#  ('sat_index2var', 0),
#  ('sat_var_count', 0),
#  ('get_options', 0),
#  ('sat_learned_clause_count', 0),
#  ('nnf_manager_new', 0),
#  ('sat_undo_decide_literal', 0),
#  ('count_vtree', 0),
#  ('count_dispatcher', 0),
#  ('nnf_save_as_dot', 0),
#  ('nnf_manager_extract_nnf', 0),
#  ('count_vtree_leaf', 0),
#  ('vtree_manager_free', 0.0),
#  ('sat_index2clause', 0),
#  ('extended_file_name', 0),
#  ('nnf_conjoin', 0),
#  ('nnf_disjoin', 0),
#  ('sat_clause_size', 0),
#  ('sat_literal_weight', 0),
#  ('bits2bytes', 0),
#  ('nnf_manager_free', 0),
#  ('init_options', 0),
#  ('sat_clause_count', 0),
#  ('nnf_decomposable', 0),
#  ('var2count', 0),
#  ('count_vtree_shannon', 0),
#  ('sat_var_occurences', 0),
#  ('compile_with_literal', 0),
#  ('sat_state_new', 0),
#  ('sat_index2literal', 0),
#  ('nnf_node_count', 0),
#  ('should_cache', 0),
#  ('vtree_print_widths', 0),
#  ('vtree_save_as_dot', 0),
#  ('compile_vtree_leaf', 0),
#  ('nnf_edge_count', 0),
#  ('allocate_manager_keys', 0),
#  ('nnf_manager_memory', 0),
#  ('nnf_count_models', 0),
#  ('nnf_load_from_file', 0),
#  ('compile_vtree', 0.0),
#  ('match_keys', 0),
#  ('count_vtree_decomposed', 0),
#  ('compile_vtree_decomposed', 0.0)]

# %%
# alternate method
# iterate over the callstack
# find the topmost function which is in target functions -> add to that fn

# target_functions_no_compile = set(filter(lambda x: not x.startswith("compile_") and not "mark" in x, target_functions))
target_functions_no_compile = target_functions

fn_pcts = {}
for fn in target_functions_no_compile:
    fn_pcts[fn] = 0

with open(PERF_FOLDED, "r") as f:
    lines = f.readlines()
    skip_section = False
    current_fn = None
    for i, line in enumerate(lines):
        line = line.strip()
        if len(line) == 0:
            break
        if line[0] == "#":
            continue
        res = match_main_line(line)
        if res:
            current_fn = res["symbol"]
            if current_fn not in target_functions_no_compile:
                skip_section = True
                continue
            skip_section = False
        else:
            if skip_section:
                continue
            pct, callstack = line.split(maxsplit=1)
            pct = float(pct.replace('%', ''))
            callstack = callstack.split(";")
            for fn in reversed(callstack):
                if fn in target_functions_no_compile:
                    if fn == current_fn:
                        fn_pcts[current_fn] += pct
                    break
fn_pcts = sorted(list(fn_pcts.items()), key=lambda x: x[1], reverse=True)
fn_pcts
# Out:
# [('sat_decide_literal', 41.53999999999999),
#  ('sat_assert_clause', 15.01),
#  ('construct_vtree_key', 14.050000000000027),
#  ('vtree_manager_new', 11.860000000000017),
#  ('compile_vtree_shannon', 4.2200000000000015),
#  ('sat_is_subsumed_clause', 2.0400000000000014),
#  ('sat_mark_var', 1.53),
#  ('lookup_cache', 1.2600000000000007),
#  ('sat_is_implied_literal', 1.2600000000000007),
#  ('sat_unmark_var', 0.9099999999999999),
#  ('sat_is_marked_var', 0.78),
#  ('compile_dispatcher', 0.7700000000000002),
#  ('vtree_is_shannon_node', 0.7700000000000002),
#  ('free_vtree_cache', 0.62),
#  ('clist_size', 0.59),
#  ('insert_cache', 0.18),
#  ('sat_clause2literals', 0.18),
#  ('drop_vtree_cache_entries', 0.18),
#  ('sat_var2pliteral', 0.18),
#  ('main', 0.18),
#  ('sat_is_instantiated_var', 0.18),
#  ('vtree_shannon_var', 0.12),
#  ('sat_state_free', 0.12),
#  ('compile_vtree_decomposed', 0.12),
#  ('sat_mark_clause', 0.11),
#  ('sat_literal2var', 0.06),
#  ('sat_is_irrelevant_var', 0.06),
#  ('sat_var2nliteral', 0.06),
#  ('sat_unmark_clause', 0.06),
#  ('var2nnf', 0.06),
#  ('free_manager_keys', 0.06),
#  ('pprint_bytes', 0),
#  ('copy_key', 0),
#  ('set_vtree_hashcode', 0),
#  ('sat_at_assertion_level', 0),
#  ('sat_clause2index', 0),
#  ('nnf_literal2node', 0),
#  ('print_error_and_exit', 0),
#  ('count_with_literal', 0),
#  ('print_vtree_cache_stats', 0),
#  ('vtree_save', 0),
#  ('nnf_entails_cnf', 0),
#  ('free_cache_entry', 0),
#  ('nnf_save_to_file', 0),
#  ('construct_vtree_cache', 0),
#  ('print_help', 0),
#  ('drop_cache_entry', 0),
#  ('c2d_version', 0),
#  ('nnf_manager_get_root', 0),
#  ('vtree_type', 0),
#  ('vtree_is_leaf', 0),
#  ('free_vtree_keys', 0),
#  ('sat_clause_of_var', 0),
#  ('sat_var2index', 0),
#  ('sat_literal2index', 0),
#  ('sat_assert_unit_clauses', 0),
#  ('nnf_count_nodes', 0),
#  ('sat_undo_assert_unit_clauses', 0),
#  ('allocate_vtree_keys', 0),
#  ('nnf_manager_save_to_file', 0),
#  ('nnf_manager_set_root', 0),
#  ('nnf_free', 0),
#  ('sat_is_marked_clause', 0),
#  ('sat_index2var', 0),
#  ('sat_var_count', 0),
#  ('get_options', 0),
#  ('sat_learned_clause_count', 0),
#  ('nnf_manager_new', 0),
#  ('sat_undo_decide_literal', 0),
#  ('count_vtree', 0),
#  ('count_dispatcher', 0),
#  ('nnf_save_as_dot', 0),
#  ('nnf_manager_extract_nnf', 0),
#  ('count_vtree_leaf', 0),
#  ('vtree_manager_free', 0),
#  ('sat_index2clause', 0),
#  ('extended_file_name', 0),
#  ('nnf_conjoin', 0),
#  ('nnf_disjoin', 0),
#  ('sat_clause_size', 0),
#  ('sat_literal_weight', 0),
#  ('bits2bytes', 0),
#  ('nnf_manager_free', 0),
#  ('init_options', 0),
#  ('sat_clause_count', 0),
#  ('nnf_decomposable', 0),
#  ('var2count', 0),
#  ('count_vtree_shannon', 0),
#  ('sat_var_occurences', 0),
#  ('compile_with_literal', 0),
#  ('sat_state_new', 0),
#  ('sat_index2literal', 0),
#  ('nnf_node_count', 0),
#  ('should_cache', 0),
#  ('vtree_print_widths', 0),
#  ('vtree_save_as_dot', 0),
#  ('compile_vtree_leaf', 0),
#  ('nnf_edge_count', 0),
#  ('allocate_manager_keys', 0),
#  ('nnf_manager_memory', 0),
#  ('nnf_count_models', 0),
#  ('nnf_load_from_file', 0),
#  ('compile_vtree', 0),
#  ('match_keys', 0),
#  ('count_vtree_decomposed', 0)]

# %%
print(sum(fn_pcts.values()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print(sum(fn_pcts.values()))
#
# AttributeError: 'list' object has no attribute 'values'
